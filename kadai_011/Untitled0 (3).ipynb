# %%
array = ["水","金","地","火","木","土","天","海","冥"]
sum = 0

for i in array:
  print(i)

while sum != 9:
  print(array[sum])
  sum = sum + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
